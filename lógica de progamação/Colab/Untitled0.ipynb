# %% [markdown]
# ### tipos de dados
# * inteiros --> int
# * float --> float (números reais)
# * booleano --> bool (verdadeiro -True/ Falso - False)
# * string --> str (Textos)
#
# ### variáveis
#
# * numero = 23
# * real = 3.14
# * teste = true
# * texto = "sou uma string"
#
# ### Tipagem dinâmica
# * número = texto/
# * numeor = 3
# * número = 3.14
#
# ### 24/3
# * if - se
# * elif -> senão se
# * else -> senão
#
# * a. == igualdade
# * b. != diferente
# * c. > maior que
# * d. < menor que
# * e. >= maior ou igual
# * f. <= menor ou igual

# %%
nome = "Pedro"
idade = 20
altura = 1.78
sabe_progamar = False

print("o", nome, "tem", idade, "anos", altura, "m. Sabe progamar?:", sabe_progamar)
print("o " + str(nome) + " tem " + str(idade) + "anos " + str(altura) + "m. Sabe progamar?:" + str(sabe_progamar))
# Out:
# o Pedro tem 20 anos 1.78 m. Sabe progamar?: False
# o Pedro tem 20anos 1.78m. Sabe progamar?:False

# %%
salario = 12000
parcelas = salario / 7
print(f"{parcelas:.2f}")
# Out:
# 1714.29

# %%
print(f"{10:4d}")
print(f"{100:4d}")
print(f"{1000:4d}")
# Out:
#   10
#  100
# 1000

# %%
nota=input("digite sua nota:")
presença=input("digite sua presença presença:"1)
if(float(nota) > 7):
  print("Raça absoluta além da consiência")
else:
  if(float(nota) >= 6):
      if float(presença) >= 75:
        print("até de olhos vendados")
      else:
        print("se fu---")
  else:
    print("se fu---")
# Out:
# digite sua nota:1
# digite sua presença presença:1
# se fu---

# %%
nota=input("digite sua nota:")
presença=input("digite sua presença presença:")
if(float(nota) > 10):
  print("para de mentir fdp")
else:
  if(float(nota) > 7):
    print("Raça absoluta além da consiência")
  else:
    if(float(nota) >= 6):
      if float(presença) >= 75:
        print("até de olhos vendados")
      else:
        print("se fu---")
    else:
     print("se fu---")
# Out:
# digite sua nota:6
# digite sua presença presença:80
# até de olhos vendados

# %%
nome=input("nome: ")
sobrenome=input("sobrenome: ")
print(nome,sobrenome)
# Out:
# nome: apa
# sobrenome: a
# apa a

# %%
print("\nx       x\n x     x\n  x   x\n    x\n  x   x\n x     x\nx       x")
# Out:
# x       x
#  x     x
#   x   x
#     x
#   x   x
#  x     x
# x       x

# %%
z=int(input("dia do aniversário: "))
x=input("mês do aniversário: ")
a=int(input("dia de hj: "))
b=input("mês de hj: ")
if x == "janeiro" or "1":
  m=0
if x == "fevereiro" or "2":
  m=31
if x == "março" or "3":
  m=59
if x == "abril" or "4":
  m=90
if x == "maio" or "5":
  m=120
if x == "junho" or "6":
  m=151
if x == "julho" or "7":
  m=181
if x == "agosto" or "8":
  m=212
if x == "setempro" or "9":
  m=242
if x == "outubro" or "10":
  m=273
if x == "novembro": or "11"
  m=303
if x == "dezembro" or "12":
  m=334
if b == "janeiro" or "1":
  d=0
if b == "fevereiro" or "2":
  d=31
if b == "março": or "3"
  d=59
if b == "abril" or "4":
  d=90
if b == "maio" or "5":
  d=120
if b == "junho" or "6":
  d=151
if b == "julho" or "7":
  d=181
if b == "agosto" or "8":
  d=212
if b == "setempro" or "9":
  d=242
if b == "outubro" or "10":
  d=273
if b == "novembro" or "11":
  d=303
if d == "dezembro" or "12":
  d=334
h = (int(z+m)-int(a+d))
print(h)
if h > 0:
  print("faltam:",h,"dia(s) pro seu anivérsario")
if h < 0:
  print("faz",-h,"dia(s) desde o seu aniversário")
if h==0:
  print("hj é a por-- do seu aniversário. pq vc ta querendo saber isso. caso vc ainda queira saber. FALTAM 365 PRO DIA QUE SUA MÃE TE PARIU")
# Out:
# dia do aniversário: 12
# mês do aniversário: junho
# dia de hj: 31
# mês de hj: março
# 73
# faltam: 73 dia(s) pro seu anivérsario

# %%
P=input("preço: ")
print("então...  \ngostei de vc    \nvo faze um preço de amigo pra tu")
D = float(P)*float(0.8)
d = float(P)*float(0.2)
print(float(D),"oq tu acha?\nvai economizar",float
 (d),"conto")
# Out:
# preço: 1
# então...
# gostei de vc
# vo faze um preço de amigo pra tu
# 0.8 oq tu acha?
# vai economizar 0.2 conto

# %%
P=input("preço: ")
N=input("quanto de desconto vc quer negociar:")
print("então...  \ngostei de vc e te achei um eximio negociador   \nvo faze um preço de amigo pra tu")
D = float(P)*float(100-float(N))/float(100)
d = float(P)*float(N)/float(100)
print(float(D),"conto ent?\nta",float(d),"mais barato")
# Out:
# preço: 10
# quanto de desconto vc quer negociar: 20
# então...
# gostei de vc e te achei um eximio negociador
# vo faze um preço de amigo pra tu
# 8.0 conto ent?
# ta 2.0 mais barato

# %%
p=input("primeiro: ")
s=input("segundo: ")
t=input("terceiro: ")
M=(float(p)+float(t)+float(s))/float(3)
print(float(M))
# Out:
# primeiro: 10
# segundo: 20
# terceiro: 0
# 10.0

# %%
p=input("primeiro: ")
s=input("segundo: ")
t=input("terceiro: ")
q=input("quarto: ")
mg=(float(q)*float(t)*float(s)*float(p))**float(0.25)
mh=float(4)/(float(p)**float(-1)+float(s)**float(-1)+float(t)**float(-1)+float(q)**float(-1))
M=(float(p)+float(t)+float(s)+float(q))/float(4)
print("média aritmética:",M)
print("média geométrica:",mg)
print("média harmonica:",mh)
# Out:
# primeiro: 2
# segundo: 2
# terceiro: 2
# quarto: 2
# média aritmética: 2.0
# média geométrica: 2.0
# média harmonica: 2.0

# %%
p=input("primeiro: ")
s=input("segundo: ")
t=input("terceiro: ")
if p > s:
  if p > t:
    print(p)
if s > p:
  if s > t:
    print(s)
if t > s:
  if t > p:
    print(t)
if t == s and s > p or s == p and s>t:
  print(s)
if p == t and t > s:
  print(t)
if p==t and p==s:
  print(p)
# Out:
# primeiro: 2
# segundo: 2
# terceiro: 2
# 2

# %%
p=input("primeiro: ")
s=input("segundo: ")
t=input("terceiro: ")
if p >= s and p >=t:
  print(p)
  if s >=t:
   print(s)
   print(t)
if s > p and s > t:
  print(s)
  if p >=t:
   print(p)
   print(t)
  else:
   print(t)
   print(p)
# Out:
# primeiro: 4
# segundo: 7
# terceiro: 2
# 7
# 4
# 2

# %%
p=input("primeiro: ")
s=input("segundo: ")
t=input("terceiro: ")
if p <= s and p <= t:
  print(p)
  if s <= t:
    print(s)
    print(t)
  else:
    print(t)
    print(s)
if s < t and s < p:
  print(s)
  if p <= t:
    print(p)
    print(t)
  else:
    print(t)
    print(p)
if t<s and t <p:
  print(t)
  if s <= p:
    print(s)
    print(p)
  else:
    print(p)
    print(s)
# Out:
# primeiro: 6
# segundo: 4
# terceiro: 2
# 2
# 4
# 6

# %%
n = -1
while n < 0 or n >10:
  n = int(input("digite um inteiro entre 0 e 10: "))
