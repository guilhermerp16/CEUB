# %%
type(clube_paulistas), type(4), type(3.14), type(True), type("Casa")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d54ef8608bb4> in <cell line: 0>()
# ----> 1 type(clube_paulistas), type(4), type(3.14), type(True), type("Casa")
#
# NameError: name 'clube_paulistas' is not defined

# %%
paulista = ['santos','palmeiras','corintias','mirasol','brasileirão']

cariocas = ['fluminense','botafogo','vasco','flamengo']

type(paulista), type(4), type(True), type(3)
# Out:
# (list, int, bool, int)

# %%
#acessando elementos de uma lista: indice
print(paulista[0])
# Out:
# santos

# %%
#[]start: stop ; step]
paulista[::-1]
# Out:
# ['brasileirão', 'mirasol', 'corintias', 'palmeiras', 'santos']

# %%
variados = ['santos', 12, 3.13, True, ["outra",'lista']

            variados[-1][0]
